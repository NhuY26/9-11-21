# %% [markdown]
# <a href="https://colab.research.google.com/github/NhuY26/9-11/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Tuân thủ nguyên tắc 5K để phòng chống COVID")
# Out:
# Tuân thủ nguyên tắc 5K để phòng chống COVID
